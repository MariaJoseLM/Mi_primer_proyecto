# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaJoseLM/Mi_primer_proyecto/blob/main/mi_modulo_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mi_modulo.py
def saludar(nombre):
    print(f"Hola, {nombre}!")


def calcular_suma(a, b):
    return a + b
